# %%
import pandas as pd
import numpy as np

proteinGroups = pd.read_csv('../../resources/raw/combined/txt/proteinGroups.txt', sep='\t')
allPeptides = pd.read_csv('../../resources/raw/combined/txt/allPeptides.txt', sep='\t')
Peptides = pd.read_csv('../../resources/raw/combined/txt/peptides.txt', sep='\t')
summary = pd.read_csv('../../resources/raw/combined/txt/summary.txt', sep='\t')

# %%
allPeptides
# Out:
#       Raw file   Type  Charge        m/z        Mass  Uncalibrated m/z
# 0        CiCs5  MULTI       7  400.02525  2793.12580         400.02479  \
# 1        CiCs5  MULTI       7  400.02551  2793.12770         400.02506
# 2        CiCs5  MULTI       7  400.10656  2793.69500         400.10611
# 3        CiCs5  MULTI       6  400.24805  2395.44460         400.24759
# 4        CiCs5  MULTI       4  400.23494  1596.91070         400.23513
# ...        ...    ...     ...        ...         ...               ...
# 48794    CiCs5  MULTI       1  869.46978   868.46250         869.46974
# 48795    CiCs5  MULTI       1  869.46958   868.46230         869.46953
# 48796    CiCs5  MULTI       1  869.46944   868.46216         869.46940
# 48797    CiCs5  MULTI       3  870.13935  2607.39620         870.14060
# 48798    CiCs5  MULTI       1  869.52560   868.51832         869.52556
#
#        Number of data points  Number of scans  Number of isotopic peaks  PIF
# ...

# %%
c = allPeptides['Charge']
print(type(c))
c
# Out:
# <class 'pandas.core.series.Series'>
# 0        7
# 1        7
# 2        7
# 3        6
# 4        4
#         ..
# 48794    1
# 48795    1
# 48796    1
# 48797    3
# 48798    1
# Name: Charge, Length: 48799, dtype: int64

# %%
allPeptides.columns
# Out:
# Index(['Raw file', 'Type', 'Charge', 'm/z', 'Mass', 'Uncalibrated m/z',
#        'Number of data points', 'Number of scans', 'Number of isotopic peaks',
#        'PIF', 'Mass fractional part', 'Mass deficit', 'Mass precision [ppm]',
#        'Max intensity m/z 0', 'Retention time', 'Retention length',
#        'Retention length (FWHM)', 'Min scan number', 'Max scan number',
#        'Identified', 'Reverse', 'MS/MS IDs', 'Sequence', 'Length',
#        'Modifications', 'Modified sequence', 'Proteins', 'Score', 'PEP',
#        'Intensity', 'Intensities', 'Isotope pattern', 'MS/MS count',
#        'MSMS scan numbers', 'MSMS isotope indices'],
#       dtype='object')

# %%
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 48794   NaN
# 48795   NaN
# 48796   NaN
# 48797   NaN
# 48798   NaN
# Name: Sequence, Length: 48799, dtype: float64
